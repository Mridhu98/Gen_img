# %%
import diffusers, transformers, torch
print("Diffusers:", diffusers.__version__)
print("Transformers:", transformers.__version__)
print("Torch:", torch.__version__)
# Out:
# Diffusers: 0.35.1
# Transformers: 4.36.2
# Torch: 2.8.0+cu126

# %%
from diffusers import StableDiffusionPipeline
import torch

# %%
# Install required packages first
# pip install torch torchvision transformers pillow

from PIL import Image
import torch
from transformers import BlipProcessor, BlipForConditionalGeneration

# 1. Load the BLIP processor and model
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")

# 2. Load your image
image_path = "/content/dog1.jpeg"  # replace with your image path
image = Image.open(image_path).convert("RGB")

# 3. Preprocess image and prepare input for the model
inputs = processor(images=image, return_tensors="pt")

# 4. Generate caption (you can adjust max_length as needed)
with torch.no_grad():
    output_ids = model.generate(**inputs, max_length=50)

# 5. Decode the output ids to text
caption = processor.decode(output_ids[0], skip_special_tokens=True)

print("Generated Caption:", caption)

# %%
# Install required packages first
# pip install torch torchvision transformers pillow

from PIL import Image
import torch
from transformers import BlipProcessor, BlipForConditionalGeneration

# 1. Load the BLIP processor and model
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")

# 2. Load your image
image_path = "/content/dog2.jpeg"  # replace with your image path
image = Image.open(image_path).convert("RGB")

# 3. Preprocess image and prepare input for the model
inputs = processor(images=image, return_tensors="pt")

# 4. Generate caption (you can adjust max_length as needed)
with torch.no_grad():
    output_ids = model.generate(**inputs, max_length=50)

# 5. Decode the output ids to text
caption = processor.decode(output_ids[0], skip_special_tokens=True)

print("Generated Caption:", caption)

# %%
pip install -q transformers==4.26.0

# %%
pip install transformers==4.36.2 --no-build-isolation

# %%
from diffusers import StableDiffusionPipeline
import torch

# Load pipeline
pipe = StableDiffusionPipeline.from_pretrained(
    "runwayml/stable-diffusion-v1-5",
    dtype=torch.float16,
)
pipe = pipe.to("cuda")

# Your prompt
prompt = "A Tiger spotted in Jungle"

# Number of images to generate
num_images = 5

for i in range(num_images):
    image = pipe(prompt).images[0]
    image.save(f"tiger_jungle_{i+1}.png")
    print(f"Image {i+1} saved.")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipython-input-1887315863.py in <cell line: 0>()
# ----> 1 from diffusers import StableDiffusionPipeline
#       2 import torch
#       3
#       4 # Load pipeline
#       5 pipe = StableDiffusionPipeline.from_pretrained(
#
# /usr/local/lib/python3.12/dist-packages/diffusers/__init__.py in <module>
#       3 from typing import TYPE_CHECKING
#       4
# ----> 5 from .utils import (
#       6     DIFFUSERS_SLOW_IMPORT,
#       7     OptionalDependencyNotAvailable,
#
# /usr/local/lib/python3.12/dist-packages/diffusers/utils/__init__.py in <module>
#      36 from .deprecation_utils import deprecate
#      37 from .doc_utils import replace_example_docstring
# ---> 38 from .dynamic_modules_utils import get_class_from_dynamic_module
#      39 from .export_utils import export_to_gif, export_to_obj, export_to_ply, export_to_video
# ...

# %%
# %pip install -U transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 70.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.57.0
#     Uninstalling transformers-4.57.0:
#       Successfully uninstalled transformers-4.57.0
# ...

# %%
# %pip install -U transformers

# %%
pip install diffusers==0.24.0 transformers==4.36.2 accelerate==0.25.0 safetensors==0.4.2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.8/126.8 kB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 66.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 138.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 23.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 75.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: safetensors
#     Found existing installation: safetensors 0.6.2
#     Uninstalling safetensors-0.6.2:
#       Successfully uninstalled safetensors-0.6.2
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.35.1
#     Uninstalling diffusers-0.35.1:
#       Successfully uninstalled diffusers-0.35.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.35.2
#     Uninstalling transformers-4.35.2:
#       Successfully uninstalled transformers-4.35.2
#   Attempting uninstall: accelerate
# ...

# %%
import sys
sys.path.append('./')
import dnnlib
import legacy
import torch
import numpy as np
from PIL import Image

network_pkl = r"C:\Users\rajan\Documents\GenAi practicals\stylegan2\stylegan2\stylegan2-ada-pytorch\models\ffhq.pkl"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

with open(network_pkl, "rb") as f:
    G = legacy.load_network_pkl(f)["G_ema"].to(device)

#Generate random latent vector
z = torch.randn([1, G.z_dim], device = device)

#Synthesize Image
img = G(z,None)
img = (img.permute(0,2,3,1) * 127.5+128).clamp(0,255).to(torch.uint8)
#img = Image.fromarray(img[0].cuda().numpy(), "RGB")
img = Image.fromarray(img[0].cpu().numpy(), "RGB")
#save Image
img.save("stylegan2_output.png")
img.show()
print("Image generated and saved as stylegan2_output.png")
